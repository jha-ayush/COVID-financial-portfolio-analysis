# %%
pip install polygon-api-client
# Out:
# Requirement already satisfied: polygon-api-client in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (0.2.11)
# Requirement already satisfied: requests>=2.22.0 in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from polygon-api-client) (2.27.1)
# Requirement already satisfied: websockets>=8.0.2 in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from polygon-api-client) (10.4)
# Requirement already satisfied: websocket-client>=0.56.0 in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from polygon-api-client) (0.58.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests>=2.22.0->polygon-api-client) (2022.9.24)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests>=2.22.0->polygon-api-client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests>=2.22.0->polygon-api-client) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from requests>=2.22.0->polygon-api-client) (1.26.9)
# Requirement already satisfied: six in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from websocket-client>=0.56.0->polygon-api-client) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fire
# Out:
# Requirement already satisfied: fire in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (0.4.0)
# Requirement already satisfied: termcolor in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from fire) (2.0.1)
# Requirement already satisfied: six in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from fire) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install questionary
# Out:
# Requirement already satisfied: questionary in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (1.10.0)
# Requirement already satisfied: prompt_toolkit<4.0,>=2.0 in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from questionary) (3.0.20)
# Requirement already satisfied: wcwidth in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from prompt_toolkit<4.0,>=2.0->questionary) (0.2.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install load_dotenv
# Out:
# Collecting load_dotenv
#   Downloading load_dotenv-0.1.0-py3-none-any.whl (7.2 kB)
# Requirement already satisfied: python-dotenv in /Users/christinepham/opt/anaconda3/envs/dev/lib/python3.7/site-packages (from load_dotenv) (0.21.0)
# Installing collected packages: load-dotenv
# Successfully installed load-dotenv-0.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#from polygon import RESTClient

# %%
#import the necessary modules
import pandas as pd
#questionary
from pathlib import Path
import fire
import questionary
#API
import os
import json
import requests
from dotenv import load_dotenv
from MCForecastTools import MCSimulation
# %matplotlib inline

# %%
from IPython.display import display_html

# %%
POLYGON_API_KEY = 'JQfBpF3NpcYjuBdMiXeUr6q54XafY_pQ'

# %%
ticker_list = ["AMZN", "RTH","AMT", "IYR", "XOM", "XLE"]

# %%
import requests
import datetime
from time import sleep
from tqdm import tqdm
def get_prices(start_date,end_date,universe):
    data = pd.DataFrame()
    # end_at = datetime.datetime.now() 
    # begin_from = end_at + datetime.timedelta(days=-5000)
    for t in tqdm(universe):
        print(t)
        print(len(data))
        # for start in pd.date_range(start = begin_from, end = end_at,normalize=True,freq = '88D'):
        #     end = start + datetime.timedelta(days = 88)
        #     end = str(int((end - datetime.datetime(1970,1,1)).total_seconds()))
        #     start = str(int((start - datetime.datetime(1970,1,1)).total_seconds()))
        try:
            r = requests.get(f'https://api.polygon.io/v2/aggs/ticker/{t}/range/1/day/{start_date}/{end_date}?apiKey={POLYGON_API_KEY}')
        except json.JSONDecodeError:
            pass
        try:
            # print(r.json())
            temp_data = pd.DataFrame(r.json()['results'])
            temp_data['ticker'] = t
            data = data.append(temp_data, ignore_index=True)
            print(t+':'+str(pd.to_datetime(start_date, unit='s'))+':'+str(pd.to_datetime(end_date, unit='s')))
        except KeyError:
            print(f'{t} was not found')
            pass
        except ValueError:
            pass
        except ConnectionError as error:
            print(error)
            sleep(200)
            continue
        except TimeoutError as error:
            print(error)
            sleep(200)
            continue
        sleep(0.25)
#     data.to_csv(file_name,index = False)
    data.t = pd.to_datetime(data.t, unit = 'ms')
    columns_name = {'t': 'time', 'o': 'Open', 'c': 'Close', 'h': 'High', 'l': 'Low', 'v': 'Volume'} 
    data= data.rename(columns = columns_name)
    data = data[['time','ticker','Open', 'Close','High', 'Low', 'Volume']]
    data = data.set_index(['time', 'ticker'])
    data = data.pct_change()
    data = data.dropna()
    #data.to_csv(file_name, index = False)
    return data

# %%
# Create `start_date` and `end_date` variables for the period during the pandemic
start_date = "2020-03-01"
end_date = "2021-03-01"
all_data = get_prices(start_date=start_date, end_date=end_date, universe=ticker_list)
# Out:
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
# AMZN
# 0
#  17%|███████▌                                     | 1/6 [00:00<00:03,  1.41it/s]
# RTH
# 252
#  33%|███████████████                              | 2/6 [00:01<00:02,  1.56it/s]
# AMT
# 504
#  50%|██████████████████████▌                      | 3/6 [00:01<00:01,  1.50it/s]
# IYR
# 756
#  67%|██████████████████████████████               | 4/6 [00:02<00:01,  1.59it/s]
# XOM
# 1008
#  83%|█████████████████████████████████████▌       | 5/6 [00:03<00:00,  1.65it/s]
# XLE
# 1260
# 100%|█████████████████████████████████████████████| 6/6 [00:03<00:00,  1.61it/s]

# %%
all_data.index
# Out:
# MultiIndex([('2020-03-03 05:00:00', 'AMZN'),
#             ('2020-03-04 05:00:00', 'AMZN'),
#             ('2020-03-05 05:00:00', 'AMZN'),
#             ('2020-03-06 05:00:00', 'AMZN'),
#             ('2020-03-09 04:00:00', 'AMZN'),
#             ('2020-03-10 04:00:00', 'AMZN'),
#             ('2020-03-11 04:00:00', 'AMZN'),
#             ('2020-03-12 04:00:00', 'AMZN'),
#             ('2020-03-13 04:00:00', 'AMZN'),
#             ('2020-03-16 04:00:00', 'AMZN'),
#             ...
#             ('2021-02-16 05:00:00',  'XLE'),
#             ('2021-02-17 05:00:00',  'XLE'),
#             ('2021-02-18 05:00:00',  'XLE'),
#             ('2021-02-19 05:00:00',  'XLE'),
#             ('2021-02-22 05:00:00',  'XLE'),
#             ('2021-02-23 05:00:00',  'XLE'),
#             ('2021-02-24 05:00:00',  'XLE'),
#             ('2021-02-25 05:00:00',  'XLE'),
#             ('2021-02-26 05:00:00',  'XLE'),
#             ('2021-03-01 05:00:00',  'XLE')],
#            names=['time', 'ticker'], length=1511)

# %%
idx = pd.IndexSlice

# %%
AMZN_daily_returns_df = all_data.loc[idx[:,'AMZN'],['Close']]
AMZN_daily_returns_df
# Out:
#                                Close
# time                ticker
# 2020-03-03 05:00:00 AMZN   -0.023010
# 2020-03-04 05:00:00 AMZN    0.035013
# 2020-03-05 05:00:00 AMZN   -0.026217
# 2020-03-06 05:00:00 AMZN   -0.011923
# 2020-03-09 04:00:00 AMZN   -0.052854
# ...                              ...
# 2021-02-23 05:00:00 AMZN    0.004326
# 2021-02-24 05:00:00 AMZN   -0.010947
# 2021-02-25 05:00:00 AMZN   -0.032400
# 2021-02-26 05:00:00 AMZN    0.011700
# 2021-03-01 05:00:00 AMZN    0.017204
#
# [251 rows x 1 columns]

# %%
RTH_daily_returns_df = all_data.loc[idx[:,'RTH'],['Close']]
RTH_daily_returns_df
# Out:
#                                Close
# time                ticker
# 2020-03-02 05:00:00 RTH    -0.246760
# 2020-03-03 05:00:00 RTH    -0.025206
# 2020-03-04 05:00:00 RTH     0.039796
# 2020-03-05 05:00:00 RTH    -0.022688
# 2020-03-06 05:00:00 RTH    -0.009098
# ...                              ...
# 2021-02-23 05:00:00 RTH    -0.007181
# 2021-02-24 05:00:00 RTH    -0.009183
# 2021-02-25 05:00:00 RTH    -0.023932
# 2021-02-26 05:00:00 RTH    -0.001041
# 2021-03-01 05:00:00 RTH     0.016992
#
# [252 rows x 1 columns]

# %%
AMT_daily_returns_df = all_data.loc[idx[:,'AMT'],['Close']]
AMT_daily_returns_df
# Out:
#                                Close
# time                ticker
# 2020-03-02 05:00:00 AMT     0.541195
# 2020-03-03 05:00:00 AMT     0.007892
# 2020-03-04 05:00:00 AMT     0.037132
# 2020-03-05 05:00:00 AMT    -0.018755
# 2020-03-06 05:00:00 AMT    -0.002511
# ...                              ...
# 2021-02-23 05:00:00 AMT    -0.008442
# 2021-02-24 05:00:00 AMT     0.007214
# 2021-02-25 05:00:00 AMT    -0.000133
# 2021-02-26 05:00:00 AMT    -0.038354
# 2021-03-01 05:00:00 AMT    -0.010919
#
# [252 rows x 1 columns]

# %%
IYR_daily_returns_df = all_data.loc[idx[:,'IYR'],['Close']]
IYR_daily_returns_df
# Out:
#                                Close
# time                ticker
# 2020-03-02 05:00:00 IYR    -0.571455
# 2020-03-03 05:00:00 IYR     0.000109
# 2020-03-04 05:00:00 IYR     0.038201
# 2020-03-05 05:00:00 IYR    -0.021762
# 2020-03-06 05:00:00 IYR    -0.016980
# ...                              ...
# 2021-02-23 05:00:00 IYR     0.005603
# 2021-02-24 05:00:00 IYR     0.005349
# 2021-02-25 05:00:00 IYR    -0.016848
# 2021-02-26 05:00:00 IYR    -0.015220
# 2021-03-01 05:00:00 IYR     0.002519
#
# [252 rows x 1 columns]

# %%
XOM_daily_returns_df = all_data.loc[idx[:,'XOM'],['Close']]
XOM_daily_returns_df
# Out:
#                                Close
# time                ticker
# 2020-03-02 05:00:00 XOM    -0.384721
# 2020-03-03 05:00:00 XOM    -0.047884
# 2020-03-04 05:00:00 XOM     0.021832
# 2020-03-05 05:00:00 XOM    -0.044067
# 2020-03-06 05:00:00 XOM    -0.048294
# ...                              ...
# 2021-02-23 05:00:00 XOM     0.013812
# 2021-02-24 05:00:00 XOM     0.029973
# 2021-02-25 05:00:00 XOM    -0.016578
# 2021-02-26 05:00:00 XOM    -0.024928
# 2021-03-01 05:00:00 XOM     0.037337
#
# [252 rows x 1 columns]

# %%
XLE_daily_returns_df = all_data.loc[idx[:,'XLE'],['Close']]
XLE_daily_returns_df
# Out:
#                                Close
# time                ticker
# 2020-03-02 05:00:00 XLE    -0.164894
# 2020-03-03 05:00:00 XLE    -0.030573
# 2020-03-04 05:00:00 XLE     0.023653
# 2020-03-05 05:00:00 XLE    -0.036585
# 2020-03-06 05:00:00 XLE    -0.056185
# ...                              ...
# 2021-02-23 05:00:00 XLE     0.016534
# 2021-02-24 05:00:00 XLE     0.035413
# 2021-02-25 05:00:00 XLE    -0.019288
# 2021-02-26 05:00:00 XLE    -0.023723
# 2021-03-01 05:00:00 XLE     0.025961
#
# [252 rows x 1 columns]

# %%
tech_daily_returns = pd.concat([AMZN_daily_returns_df, RTH_daily_returns_df], keys=["AMZN","RTH"])
tech_daily_returns
# Out:
#                                     Close
#      time                ticker
# AMZN 2020-03-03 05:00:00 AMZN   -0.023010
#      2020-03-04 05:00:00 AMZN    0.035013
#      2020-03-05 05:00:00 AMZN   -0.026217
#      2020-03-06 05:00:00 AMZN   -0.011923
#      2020-03-09 04:00:00 AMZN   -0.052854
# ...                                   ...
# RTH  2021-02-23 05:00:00 RTH    -0.007181
#      2021-02-24 05:00:00 RTH    -0.009183
#      2021-02-25 05:00:00 RTH    -0.023932
#      2021-02-26 05:00:00 RTH    -0.001041
#      2021-03-01 05:00:00 RTH     0.016992
#
# [503 rows x 1 columns]

# %%
RE_daily_returns = pd.concat([AMT_daily_returns_df, IYR_daily_returns_df], keys=["AMT","IYR"])
RE_daily_returns
# Out:
#                                    Close
#     time                ticker
# AMT 2020-03-02 05:00:00 AMT     0.541195
#     2020-03-03 05:00:00 AMT     0.007892
#     2020-03-04 05:00:00 AMT     0.037132
#     2020-03-05 05:00:00 AMT    -0.018755
#     2020-03-06 05:00:00 AMT    -0.002511
# ...                                  ...
# IYR 2021-02-23 05:00:00 IYR     0.005603
#     2021-02-24 05:00:00 IYR     0.005349
#     2021-02-25 05:00:00 IYR    -0.016848
#     2021-02-26 05:00:00 IYR    -0.015220
#     2021-03-01 05:00:00 IYR     0.002519
#
# [504 rows x 1 columns]

# %%
energy_daily_returns = pd.concat([XOM_daily_returns_df, XLE_daily_returns_df], keys=["XOM","XLE"])
energy_daily_returns
# Out:
#                                    Close
#     time                ticker
# XOM 2020-03-02 05:00:00 XOM    -0.384721
#     2020-03-03 05:00:00 XOM    -0.047884
#     2020-03-04 05:00:00 XOM     0.021832
#     2020-03-05 05:00:00 XOM    -0.044067
#     2020-03-06 05:00:00 XOM    -0.048294
# ...                                  ...
# XLE 2021-02-23 05:00:00 XLE     0.016534
#     2021-02-24 05:00:00 XLE     0.035413
#     2021-02-25 05:00:00 XLE    -0.019288
#     2021-02-26 05:00:00 XLE    -0.023723
#     2021-03-01 05:00:00 XLE     0.025961
#
# [504 rows x 1 columns]

# %%
#Display all sectors of the stock/ETF dataframes
dfT_style = tech_daily_returns.style.set_table_attributes("style='display:inline; margin-right:20px;'").set_caption("Tech")
dfR_style = RE_daily_returns.style.set_table_attributes("style='display:inline'").set_caption("Real Estate")
dfE_style = energy_daily_returns.style.set_table_attributes("style='display:inline'").set_caption("Energy")


display_html(dfT_style._repr_html_() + dfR_style._repr_html_() + dfE_style._repr_html_(), raw=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_00d3a_" style='display:inline; margin-right:20px;'>
#   <caption>Tech</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Close</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >&nbsp;</th>
#       <th class="index_name level1" >time</th>
#       <th class="index_name level2" >ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00d3a_level0_row0" class="row_heading level0 row0" rowspan="251">AMZN</th>
#       <th id="T_00d3a_level1_row0" class="row_heading level1 row0" >2020-03-03 05:00:00</th>
#       <th id="T_00d3a_level2_row0" class="row_heading level2 row0" >AMZN</th>
#       <td id="T_00d3a_row0_col0" class="data row0 col0" >-0.023010</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row1" class="row_heading level1 row1" >2020-03-04 05:00:00</th>
#       <th id="T_00d3a_level2_row1" class="row_heading level2 row1" >AMZN</th>
#       <td id="T_00d3a_row1_col0" class="data row1 col0" >0.035013</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row2" class="row_heading level1 row2" >2020-03-05 05:00:00</th>
#       <th id="T_00d3a_level2_row2" class="row_heading level2 row2" >AMZN</th>
#       <td id="T_00d3a_row2_col0" class="data row2 col0" >-0.026217</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row3" class="row_heading level1 row3" >2020-03-06 05:00:00</th>
#       <th id="T_00d3a_level2_row3" class="row_heading level2 row3" >AMZN</th>
#       <td id="T_00d3a_row3_col0" class="data row3 col0" >-0.011923</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row4" class="row_heading level1 row4" >2020-03-09 04:00:00</th>
#       <th id="T_00d3a_level2_row4" class="row_heading level2 row4" >AMZN</th>
#       <td id="T_00d3a_row4_col0" class="data row4 col0" >-0.052854</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row5" class="row_heading level1 row5" >2020-03-10 04:00:00</th>
#       <th id="T_00d3a_level2_row5" class="row_heading level2 row5" >AMZN</th>
#       <td id="T_00d3a_row5_col0" class="data row5 col0" >0.050655</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row6" class="row_heading level1 row6" >2020-03-11 04:00:00</th>
#       <th id="T_00d3a_level2_row6" class="row_heading level2 row6" >AMZN</th>
#       <td id="T_00d3a_row6_col0" class="data row6 col0" >-0.037509</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row7" class="row_heading level1 row7" >2020-03-12 04:00:00</th>
#       <th id="T_00d3a_level2_row7" class="row_heading level2 row7" >AMZN</th>
#       <td id="T_00d3a_row7_col0" class="data row7 col0" >-0.079221</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row8" class="row_heading level1 row8" >2020-03-13 04:00:00</th>
#       <th id="T_00d3a_level2_row8" class="row_heading level2 row8" >AMZN</th>
#       <td id="T_00d3a_row8_col0" class="data row8 col0" >0.064648</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row9" class="row_heading level1 row9" >2020-03-16 04:00:00</th>
#       <th id="T_00d3a_level2_row9" class="row_heading level2 row9" >AMZN</th>
#       <td id="T_00d3a_row9_col0" class="data row9 col0" >-0.053697</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row10" class="row_heading level1 row10" >2020-03-17 04:00:00</th>
#       <th id="T_00d3a_level2_row10" class="row_heading level2 row10" >AMZN</th>
#       <td id="T_00d3a_row10_col0" class="data row10 col0" >0.070266</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row11" class="row_heading level1 row11" >2020-03-18 04:00:00</th>
#       <th id="T_00d3a_level2_row11" class="row_heading level2 row11" >AMZN</th>
#       <td id="T_00d3a_row11_col0" class="data row11 col0" >0.012258</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row12" class="row_heading level1 row12" >2020-03-19 04:00:00</th>
#       <th id="T_00d3a_level2_row12" class="row_heading level2 row12" >AMZN</th>
#       <td id="T_00d3a_row12_col0" class="data row12 col0" >0.027831</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row13" class="row_heading level1 row13" >2020-03-20 04:00:00</th>
#       <th id="T_00d3a_level2_row13" class="row_heading level2 row13" >AMZN</th>
#       <td id="T_00d3a_row13_col0" class="data row13 col0" >-0.018523</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row14" class="row_heading level1 row14" >2020-03-23 04:00:00</th>
#       <th id="T_00d3a_level2_row14" class="row_heading level2 row14" >AMZN</th>
#       <td id="T_00d3a_row14_col0" class="data row14 col0" >0.030735</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row15" class="row_heading level1 row15" >2020-03-24 04:00:00</th>
#       <th id="T_00d3a_level2_row15" class="row_heading level2 row15" >AMZN</th>
#       <td id="T_00d3a_row15_col0" class="data row15 col0" >0.019587</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row16" class="row_heading level1 row16" >2020-03-25 04:00:00</th>
#       <th id="T_00d3a_level2_row16" class="row_heading level2 row16" >AMZN</th>
#       <td id="T_00d3a_row16_col0" class="data row16 col0" >-0.027968</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row17" class="row_heading level1 row17" >2020-03-26 04:00:00</th>
#       <th id="T_00d3a_level2_row17" class="row_heading level2 row17" >AMZN</th>
#       <td id="T_00d3a_row17_col0" class="data row17 col0" >0.036933</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row18" class="row_heading level1 row18" >2020-03-27 04:00:00</th>
#       <th id="T_00d3a_level2_row18" class="row_heading level2 row18" >AMZN</th>
#       <td id="T_00d3a_row18_col0" class="data row18 col0" >-0.028325</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row19" class="row_heading level1 row19" >2020-03-30 04:00:00</th>
#       <th id="T_00d3a_level2_row19" class="row_heading level2 row19" >AMZN</th>
#       <td id="T_00d3a_row19_col0" class="data row19 col0" >0.033603</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row20" class="row_heading level1 row20" >2020-03-31 04:00:00</th>
#       <th id="T_00d3a_level2_row20" class="row_heading level2 row20" >AMZN</th>
#       <td id="T_00d3a_row20_col0" class="data row20 col0" >-0.007246</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row21" class="row_heading level1 row21" >2020-04-01 04:00:00</th>
#       <th id="T_00d3a_level2_row21" class="row_heading level2 row21" >AMZN</th>
#       <td id="T_00d3a_row21_col0" class="data row21 col0" >-0.021552</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row22" class="row_heading level1 row22" >2020-04-02 04:00:00</th>
#       <th id="T_00d3a_level2_row22" class="row_heading level2 row22" >AMZN</th>
#       <td id="T_00d3a_row22_col0" class="data row22 col0" >0.005834</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row23" class="row_heading level1 row23" >2020-04-03 04:00:00</th>
#       <th id="T_00d3a_level2_row23" class="row_heading level2 row23" >AMZN</th>
#       <td id="T_00d3a_row23_col0" class="data row23 col0" >-0.006379</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row24" class="row_heading level1 row24" >2020-04-06 04:00:00</th>
#       <th id="T_00d3a_level2_row24" class="row_heading level2 row24" >AMZN</th>
#       <td id="T_00d3a_row24_col0" class="data row24 col0" >0.047729</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row25" class="row_heading level1 row25" >2020-04-07 04:00:00</th>
#       <th id="T_00d3a_level2_row25" class="row_heading level2 row25" >AMZN</th>
#       <td id="T_00d3a_row25_col0" class="data row25 col0" >0.007013</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row26" class="row_heading level1 row26" >2020-04-08 04:00:00</th>
#       <th id="T_00d3a_level2_row26" class="row_heading level2 row26" >AMZN</th>
#       <td id="T_00d3a_row26_col0" class="data row26 col0" >0.015609</td>
#     </tr>
#     <tr>
#       <th id="T_00d3a_level1_row27" class="row_heading level1 row27" >2020-04-09 04:00:00</th>
#       <th id="T_00d3a_level2_row27" class="row_heading level2 row27" >AMZN</th>
#       <td i

# %% [markdown]
# ### Analyzing Each Stock and ETF Individually¶

# %%
#Questionary SQL
#How much weight do you want in each stock?

# %%
#Summary statistics for AMZN stock using .std() and .mean()

# %%
#Summary statistics for RTH stock using .std() and .mean()

# %%
#Summary statistics for AMT stock using .std() and .mean()

# %%
#Summary statistics for IYR stock using .std() and .mean()

# %%
#Summary statistics for XOM stock using .std() and .mean()

# %%
#Summary statistics for XLE stock using .std() and .mean()

# %%
# Variance For Each Stock and ETF

# %%
# Covariance for Each Stock and ETF

# %%
# Calculate betas of AMZN, RTH, AMT, IYR, XOM, XLE 

# Display the beta of all stocks and ETFS

# %%
# Calculate alphas of AMZN, RTH, AMT, IYR, XOM, XLE 

# Display the alphas of all stocks and ETFS

# %% [markdown]
# ### Analyzing What Would Happen To A Portfolio in Each Sector For the Period Before the Pandemic

# %%
#Questionary SQL
#How much weight do you want in each stock?

# %%
#Portfolio Returns for Tech: use (portfolio_return = weightAMZN * meanAMZN + weightRTH * meanRTH)

# %%
#Portfolio Returns for Real Estate: use (portfolio_return = weightAMT * meanAMT + weightIYR * meanIYR)

# %%
#Portfolio Returns for Energy: use (portfolio_return = weightXOM * meanXOM + weightXLE * meanXLE)

# %%
# Using the Pandas var function, calculate the covariance of the S&P 500 using tech portfolio returns information
# The ETF SPY will represent the market

# %%
# Using the Pandas var function, calculate the covariance of the S&P 500 using Energy portfolio returns information
# The ETF SPY will represent the market

# %%
# Using the Pandas rolling function in conjunction with the var function, 
# calculate the 30-day rolling variance for the S&P 500 using tech daily returns information

# Visualize the 30-day rolling variance of the S&P 500
# Be sure to adjust the figure size and add a title

# %%
#Monte Carlo Simulation

# %%
#Box and Whisker Plot

# %%
#HVPlot

# %%
#bar plot comparing returns of all sectors

# %%
#bar plot comparing returns of all portfolio
